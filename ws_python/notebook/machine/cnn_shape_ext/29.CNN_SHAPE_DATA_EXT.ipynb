# %%
import numpy as np

# 랜덤시드 고정시키기
np.random.seed(0)

from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import array_to_img
from keras.preprocessing.image import img_to_array, load_img
from keras.preprocessing.image import load_img

# 데이터셋 불러오기
train_datagen = ImageDataGenerator(rescale=1./255, 
                                   rotation_range=15,
                                   width_shift_range=0.1,
                                   height_shift_range=0.1,
                                   shear_range=0.5,
                                   zoom_range=[0.8, 2.0],
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                   fill_mode='nearest')

# %%
img = load_img('./src/circle_k.jpg')
x = img_to_array(img)
print(x.shape) # 24 X 24 칼라 이미지
print(x)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-3d3c52356cb0> in <module>
# ----> 1 img = load_img('./src/circle_k.jpg')
#       2 x = img_to_array(img)
#       3 print(x.shape) # 24 X 24 칼라 이미지
#       4 print(x)
#
# C:\ProgramData\Anaconda3\envs\machinegpu\lib\site-packages\keras_preprocessing\image.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     493         raise ImportError('Could not import PIL.Image. '
#     494                           'The use of `array_to_img` requires PIL.')
# --> 495     img = pil_image.open(path)
#     496     if color_mode == 'grayscale':
#     497         if img.mode != 'L':
#
# C:\ProgramData\Anaconda3\envs\machinegpu\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2768
#    2769     if filename:
# -> 2770         fp = builtins.open(filename, "rb")
#    2771         exclusive_fp = True
#    2772
#
# FileNotFoundError: [Errno 2] No such file or directory: './src/circle_k.jpg'

# %%
# 3차원 배열을 4차원으로 변경
x = x.reshape((1,) + x.shape)
print(x.shape)
# Out:
# (1, 24, 24, 3)

# %%
# 훈련 폴더와 검증 폴더의 생성
import os

newfolder='./train'
if os.path.exists(newfolder) == False:
    os.mkdir(newfolder)
newfolder='./train/circle'
if os.path.exists(newfolder) == False:
    os.mkdir(newfolder)   
newfolder='./train/rectangle'
if os.path.exists(newfolder) == False:
    os.mkdir(newfolder)   
newfolder='./train/triangle'
if os.path.exists(newfolder) == False:
    os.mkdir(newfolder)  
    
newfolder='./validation'
if os.path.exists(newfolder) == False:
    os.mkdir(newfolder)
newfolder='./validation/circle'
if os.path.exists(newfolder) == False:
    os.mkdir(newfolder)   
newfolder='./validation/rectangle'
if os.path.exists(newfolder) == False:
    os.mkdir(newfolder)   
newfolder='./validation/triangle'
if os.path.exists(newfolder) == False:
    os.mkdir(newfolder)

# %% [markdown]
# ### 훈련 및 검증 이미지 생성 (생성하려는 갯수보다 +1)

# %% [markdown]
# #### 검은색 계열 훈련용 80 개

# %%
img = load_img('./src/circle_k.jpg')
x = img_to_array(img)
x = x.reshape((1,) + x.shape)
i = 0

# 이 for는 무한으로 반복되기 때문에 우리가 원하는 반복횟수를 지정하여, 지정된 반복횟수가 되면 빠져나오도록 해야함
# 폴더를 미리 제작 할것
for batch in train_datagen.flow(x, batch_size=1, 
                                   save_to_dir='./train/circle', 
                                   save_prefix='k', 
                                   save_format='jpg'):
    i += 1
    if i >= 81: 
        break
        
img = load_img('./src/rectangle_k.jpg')
x = img_to_array(img)
x = x.reshape((1,) + x.shape)
i = 0

# 이 for는 무한으로 반복되기 때문에 우리가 원하는 반복횟수를 지정하여, 지정된 반복횟수가 되면 빠져나오도록 해야함
# 폴더를 미리 제작 할것
for batch in train_datagen.flow(x, batch_size=1, 
                                   save_to_dir='./train/rectangle', 
                                   save_prefix='k', 
                                   save_format='jpg'):
    i += 1
    if i >= 81: 
        break
        
        
img = load_img('./src/triangle_k.jpg')
x = img_to_array(img)
x = x.reshape((1,) + x.shape)
i = 0

# 이 for는 무한으로 반복되기 때문에 우리가 원하는 반복횟수를 지정하여, 지정된 반복횟수가 되면 빠져나오도록 해야함
# 폴더를 미리 제작 할것
for batch in train_datagen.flow(x, batch_size=1, 
                                   save_to_dir='./train/triangle', 
                                   save_prefix='k', 
                                   save_format='jpg'):
    i += 1
    if i >= 81: 
        break

# %% [markdown]
# #### 검은색 계열 검증용 20개

# %%
img = load_img('./src/circle_k.jpg')
x = img_to_array(img)
x = x.reshape((1,) + x.shape)
i = 0

# 이 for는 무한으로 반복되기 때문에 우리가 원하는 반복횟수를 지정하여, 지정된 반복횟수가 되면 빠져나오도록 해야함
# 폴더를 미리 제작 할것
for batch in train_datagen.flow(x, batch_size=1, 
                                   save_to_dir='./validation/circle', 
                                   save_prefix='k', 
                                   save_format='jpg'):
    i += 1
    if i >= 21: 
        break
        
img = load_img('./src/rectangle_k.jpg')
x = img_to_array(img)
x = x.reshape((1,) + x.shape)
i = 0

# 이 for는 무한으로 반복되기 때문에 우리가 원하는 반복횟수를 지정하여, 지정된 반복횟수가 되면 빠져나오도록 해야함
# 폴더를 미리 제작 할것
for batch in train_datagen.flow(x, batch_size=1, 
                                   save_to_dir='./validation/rectangle', 
                                   save_prefix='k', 
                                   save_format='jpg'):
    i += 1
    if i >= 21: 
        break
        
        
img = load_img('./src/triangle_k.jpg')
x = img_to_array(img)
x = x.reshape((1,) + x.shape)
i = 0

# 이 for는 무한으로 반복되기 때문에 우리가 원하는 반복횟수를 지정하여, 지정된 반복횟수가 되면 빠져나오도록 해야함
# 폴더를 미리 제작 할것
for batch in train_datagen.flow(x, batch_size=1, 
                                   save_to_dir='./validation/triangle', 
                                   save_prefix='k', 
                                   save_format='jpg'):
    i += 1
    if i >= 21: 
        break

# %% [markdown]
# #### 빨간색 계열 훈련용 80 개

# %%
img = load_img('./src/circle_r.jpg')
x = img_to_array(img)
x = x.reshape((1,) + x.shape)
i = 0

# 이 for는 무한으로 반복되기 때문에 우리가 원하는 반복횟수를 지정하여, 지정된 반복횟수가 되면 빠져나오도록 해야함
# 폴더를 미리 제작 할것
for batch in train_datagen.flow(x, batch_size=1, 
                                   save_to_dir='./train/circle', 
                                   save_prefix='r', 
                                   save_format='jpg'):
    i += 1
    if i >= 81: 
        break
        
img = load_img('./src/rectangle_r.jpg')
x = img_to_array(img)
x = x.reshape((1,) + x.shape)
i = 0

# 이 for는 무한으로 반복되기 때문에 우리가 원하는 반복횟수를 지정하여, 지정된 반복횟수가 되면 빠져나오도록 해야함
# 폴더를 미리 제작 할것
for batch in train_datagen.flow(x, batch_size=1, 
                                   save_to_dir='./train/rectangle', 
                                   save_prefix='r', 
                                   save_format='jpg'):
    i += 1
    if i >= 81: 
        break
        
        
img = load_img('./src/triangle_r.jpg')
x = img_to_array(img)
x = x.reshape((1,) + x.shape)
i = 0

# 이 for는 무한으로 반복되기 때문에 우리가 원하는 반복횟수를 지정하여, 지정된 반복횟수가 되면 빠져나오도록 해야함
# 폴더를 미리 제작 할것
for batch in train_datagen.flow(x, batch_size=1, 
                                   save_to_dir='./train/triangle', 
                                   save_prefix='r', 
                                   save_format='jpg'):
    i += 1
    if i >= 81: 
        break

# %% [markdown]
# #### 빨간색 계열 검증용 20개

# %%
img = load_img('./src/circle_r.jpg')
x = img_to_array(img)
x = x.reshape((1,) + x.shape)
i = 0

# 이 for는 무한으로 반복되기 때문에 우리가 원하는 반복횟수를 지정하여, 지정된 반복횟수가 되면 빠져나오도록 해야함
# 폴더를 미리 제작 할것
for batch in train_datagen.flow(x, batch_size=1, 
                                   save_to_dir='./validation/circle', 
                                   save_prefix='r', 
                                   save_format='jpg'):
    i += 1
    if i >= 21: 
        break
        
img = load_img('./src/rectangle_r.jpg')
x = img_to_array(img)
x = x.reshape((1,) + x.shape)
i = 0

# 이 for는 무한으로 반복되기 때문에 우리가 원하는 반복횟수를 지정하여, 지정된 반복횟수가 되면 빠져나오도록 해야함
# 폴더를 미리 제작 할것
for batch in train_datagen.flow(x, batch_size=1, 
                                   save_to_dir='./validation/rectangle', 
                                   save_prefix='r', 
                                   save_format='jpg'):
    i += 1
    if i >= 21: 
        break
        
        
img = load_img('./src/triangle_r.jpg')
x = img_to_array(img)
x = x.reshape((1,) + x.shape)
i = 0

# 이 for는 무한으로 반복되기 때문에 우리가 원하는 반복횟수를 지정하여, 지정된 반복횟수가 되면 빠져나오도록 해야함
# 폴더를 미리 제작 할것
for batch in train_datagen.flow(x, batch_size=1, 
                                   save_to_dir='./validation/triangle', 
                                   save_prefix='r', 
                                   save_format='jpg'):
    i += 1
    if i >= 21: 
        break

# %% [markdown]
# #### 파란색 계열 훈련용 80 개

# %%
img = load_img('./src/circle_b.jpg')
x = img_to_array(img)
x = x.reshape((1,) + x.shape)
i = 0

# 이 for는 무한으로 반복되기 때문에 우리가 원하는 반복횟수를 지정하여, 지정된 반복횟수가 되면 빠져나오도록 해야함
# 폴더를 미리 제작 할것
for batch in train_datagen.flow(x, batch_size=1, 
                                   save_to_dir='./train/circle', 
                                   save_prefix='b', 
                                   save_format='jpg'):
    i += 1
    if i >= 81: 
        break
        
img = load_img('./src/rectangle_b.jpg')
x = img_to_array(img)
x = x.reshape((1,) + x.shape)
i = 0

# 이 for는 무한으로 반복되기 때문에 우리가 원하는 반복횟수를 지정하여, 지정된 반복횟수가 되면 빠져나오도록 해야함
# 폴더를 미리 제작 할것
for batch in train_datagen.flow(x, batch_size=1, 
                                   save_to_dir='./train/rectangle', 
                                   save_prefix='b', 
                                   save_format='jpg'):
    i += 1
    if i >= 81: 
        break
        
        
img = load_img('./src/triangle_b.jpg')
x = img_to_array(img)
x = x.reshape((1,) + x.shape)
i = 0

# 이 for는 무한으로 반복되기 때문에 우리가 원하는 반복횟수를 지정하여, 지정된 반복횟수가 되면 빠져나오도록 해야함
# 폴더를 미리 제작 할것
for batch in train_datagen.flow(x, batch_size=1, 
                                   save_to_dir='./train/triangle', 
                                   save_prefix='b', 
                                   save_format='jpg'):
    i += 1
    if i >= 81: 
        break

# %% [markdown]
# #### 파란색 계열 검증용 20 개

# %%
img = load_img('./src/circle_b.jpg')
x = img_to_array(img)
x = x.reshape((1,) + x.shape)
i = 0

# 이 for는 무한으로 반복되기 때문에 우리가 원하는 반복횟수를 지정하여, 지정된 반복횟수가 되면 빠져나오도록 해야함
# 폴더를 미리 제작 할것
for batch in train_datagen.flow(x, batch_size=1, 
                                   save_to_dir='./validation/circle', 
                                   save_prefix='b', 
                                   save_format='jpg'):
    i += 1
    if i >= 21: 
        break
        
img = load_img('./src/rectangle_b.jpg')
x = img_to_array(img)
x = x.reshape((1,) + x.shape)
i = 0

# 이 for는 무한으로 반복되기 때문에 우리가 원하는 반복횟수를 지정하여, 지정된 반복횟수가 되면 빠져나오도록 해야함
# 폴더를 미리 제작 할것
for batch in train_datagen.flow(x, batch_size=1, 
                                   save_to_dir='./validation/rectangle', 
                                   save_prefix='b', 
                                   save_format='jpg'):
    i += 1
    if i >= 21: 
        break
        
        
img = load_img('./src/triangle_b.jpg')
x = img_to_array(img)
x = x.reshape((1,) + x.shape)
i = 0

# 이 for는 무한으로 반복되기 때문에 우리가 원하는 반복횟수를 지정하여, 지정된 반복횟수가 되면 빠져나오도록 해야함
# 폴더를 미리 제작 할것
for batch in train_datagen.flow(x, batch_size=1, 
                                   save_to_dir='./validation/triangle', 
                                   save_prefix='b', 
                                   save_format='jpg'):
    i += 1
    if i >= 21: 
        break

# %%
import warnings
warnings.filterwarnings(action='ignore')

import numpy as np
import tensorflow as tf

# %%
data = [
  [1, 12],
  [2, 14],
  [5, 20],
  [13, 36],
  [17, 44],
  [19, 48],  
  [30, 70],
  [37, 84],
  [43, 96],
  [50, 110]  
]

x = [row[0] for row in data]
print(x)

yr = [row[1] for row in data]
print(yr)

# 최적값을 모름으로 균등 분포 지원 난수 생성
# tf.random_uniform(shape, 최소값, 최대값)
a = tf.Variable(tf.random_uniform([1], 0, 10, dtype=tf.float64, seed=0), name='a')
b = tf.Variable(tf.random_uniform([1], 0, 100, dtype=tf.float64, seed=0), name='b')
# Out:
# [1, 2, 5, 13, 17, 19, 30, 37, 43, 50]
# [12, 14, 20, 36, 44, 48, 70, 84, 96, 110]

# %%
def train(learning_rate):
    print('학습률:', learning_rate)
    
    y = a * x + b
    rmse = tf.sqrt(tf.reduce_mean(tf.square((y) - yr))) # 평균 제곱근 오차
    gradient_decent = tf.train.GradientDescentOptimizer(learning_rate).minimize(rmse)
    session = tf.Session() # tensorflow 실행 객체 생성
    session.run(tf.global_variables_initializer()) # 초기화

    for step in range(116001): # 0 ~ 116000
        session.run(gradient_decent) # 학습 실행, 오차 감소 진행
        if step % 2000 == 0:  # 2000번마다 결과 출력
            v_rmse = session.run(rmse)  # 평균 제곱근 오차, y - y_data → (a * x_data + b) - ydata
            v_a = session.run(a)        # 기울기, 난수로 생성
            v_b = session.run(b)        # Y 절편, 난수로 생성
            # Epoch: 반복 횟수
            print("Epoch: %.f, RMSE = %.04f, 기울기 a = %.4f, y 절편 b = %.4f" % (step, v_rmse, v_a, v_b))

    # print('학습된 선형회귀 공식: y = %.1fx + %.d' % (v_a, v_b))  # y = 2.3x + 79
    
    return v_rmse, v_a, v_b

# %%
print(np.arange(0.0, 0.005, 0.001))
# Out:
# [0.    0.001 0.002 0.003 0.004]

# %%
# 학습 함수 train() 호출
v_rmse_min = 0;
v_a_min = 0;
v_b_min = 0;

for learning_rate in np.arange(0.0, 0.005, 0.001):
    v_rmse, v_a, v_b = train(learning_rate)
    if (learning_rate == 0.0): # 초기값 적용
        v_rmse_min = v_rmse
        v_a_min = v_a
        v_b_min = v_b
    else:
        if v_rmse_min > v_rmse:  # 최소의 오차를 찾기위해 비교하는 과정
            v_rmse_min = v_rmse  # 더 작은 오차가 발견되면 기존 값을 교체
            v_a_min = v_a
            v_b_min = v_b
    print("v_rmse_min=%.4f v_a_min")

print('최소의 평균 제곱근 오차:', v_rmse_min)    
print('학습된 선형회귀 공식: f(x) = %.4fx + %.4f' % (v_a_min, v_b_min))
# Out:
# 학습률: 0.0
# Epoch: 0, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 2000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 4000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 6000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 8000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 10000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 12000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 14000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 16000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 18000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 20000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 22000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 24000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 26000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 28000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 30000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 32000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 34000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 36000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 38000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 40000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 42000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 44000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 46000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 48000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 50000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 52000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 54000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 56000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 58000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 60000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 62000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 64000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 66000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 68000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 70000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 72000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 74000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 76000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 78000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 80000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 82000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 84000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 86000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 88000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 90000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 92000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 94000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 96000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 98000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 100000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 102000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 104000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 106000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 108000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 110000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 112000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 114000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# Epoch: 116000, RMSE = 226.0966, 기울기 a = 8.0690, y 절편 b = 80.6901
# v_rmse_min=%.4f v_a_min
# 학습률: 0.001
# Epoch: 0, RMSE = 225.3761, 기울기 a = 8.0422, y 절편 b = 80.6892
# Epoch: 2000, RMSE = 42.1471, 기울기 a = -0.0163, y 절편 b = 79.3483
# Epoch: 4000, RMSE = 41.4090, 기울기 a = 0.0190, y 절편 b = 78.1338
# Epoch: 6000, RMSE = 40.6709, 기울기 a = 0.0543, y 절편 b = 76.9193
# Epoch: 8000, RMSE = 39.9328, 기울기 a = 0.0896, y 절편 b = 75.7048
# Epoch: 10000, RMSE = 39.1946, 기울기 a = 0.1249, y 절편 b = 74.4903
# Epoch: 12000, RMSE = 38.4565, 기울기 a = 0.1602, y 절편 b = 73.2758
# Epoch: 14000, RMSE = 37.7184, 기울기 a = 0.1955, y 절편 b = 72.0613
# Epoch: 16000, RMSE = 36.9803, 기울기 a = 0.2308, y 절편 b = 70.8468
# Epoch: 18000, RMSE = 36.2422, 기울기 a = 0.2662, y 절편 b = 69.6324
# Epoch: 20000, RMSE = 35.5040, 기울기 a = 0.3015, y 절편 b = 68.4179
# Epoch: 22000, RMSE = 34.7659, 기울기 a = 0.3368, y 절편 b = 67.2034
# Epoch: 24000, RMSE = 34.0278, 기울기 a = 0.3721, y 절편 b = 65.9889
# Epoch: 26000, RMSE = 33.2897, 기울기 a = 0.4074, y 절편 b = 64.7744
# Epoch: 28000, RMSE = 32.5515, 기울기 a = 0.4427, y 절편 b = 63.5599
# Epoch: 30000, RMSE = 31.8134, 기울기 a = 0.4780, y 절편 b = 62.3454
# Epoch: 32000, RMSE = 31.0753, 기울기 a = 0.5133, y 절편 b = 61.1309
# Epoch: 34000, RMSE = 30.3372, 기울기 a = 0.5487, y 절편 b = 59.9164
# Epoch: 36000, RMSE = 29.5991, 기울기 a = 0.5840, y 절편 b = 58.7019
# Epoch: 38000, RMSE = 28.8609, 기울기 a = 0.6193, y 절편 b = 57.4874
# Epoch: 40000, RMSE = 28.1228, 기울기 a = 0.6546, y 절편 b = 56.2729
# Epoch: 42000, RMSE = 27.3847, 기울기 a = 0.6899, y 절편 b = 55.0584
# Epoch: 44000, RMSE = 26.6466, 기울기 a = 0.7252, y 절편 b = 53.8439
# Epoch: 46000, RMSE = 25.9085, 기울기 a = 0.7605, y 절편 b = 52.6294
# Epoch: 48000, RMSE = 25.1703, 기울기 a = 0.7958, y 절편 b = 51.4150
# Epoch: 50000, RMSE = 24.4322, 기울기 a = 0.8311, y 절편 b = 50.2005
# Epoch: 52000, RMSE = 23.6941, 기울기 a = 0.8665, y 절편 b = 48.9860
# Epoch: 54000, RMSE = 22.9560, 기울기 a = 0.9018, y 절편 b = 47.7715
# Epoch: 56000, RMSE = 22.2179, 기울기 a = 0.9371, y 절편 b = 46.5570
# Epoch: 58000, RMSE = 21.4797, 기울기 a = 0.9724, y 절편 b = 45.3425
# Epoch: 60000, RMSE = 20.7416, 기울기 a = 1.0077, y 절편 b = 44.1280
# Epoch: 62000, RMSE = 20.0035, 기울기 a = 1.0430, y 절편 b = 42.9135
# Epoch: 64000, RMSE = 19.2654, 기울기 a = 1.0783, y 절편 b = 41.6990
# Epoch: 66000, RMSE = 18.5273, 기울기 a = 1.1136, y 절편 b = 40.4845
# Epoch: 68000, RMSE = 17.7891, 기울기 a = 1.1490, y 절편 b = 39.2700
# Epoch: 70000, RMSE = 17.0510, 기울기 a = 1.1843, y 절편 b = 38.0555
# Epoch: 72000, RMSE = 16.3129, 기울기 a = 1.2196, y 절편 b = 36.8410
# Epoch: 74000, RMSE = 15.5748, 기울기 a = 1.2549, y 절편 b = 35.6265
# Epoch: 76000, RMSE = 14.8367, 기울기 a = 1.2902, y 절편 b = 34.4121
# Epoch: 78000, RMSE = 14.0985, 기울기 a = 1.3255, y 절편 b = 33.1976
# Epoch: 80000, RMSE = 13.3604, 기울기 a = 1.3608, y 절편 b = 31.9831
# Epoch: 82000, RMSE = 12.6223, 기울기 a = 1.3961, y 절편 b = 30.7686
# Epoch: 84000, RMSE = 11.8842, 기울기 a = 1.4315, y 절편 b = 29.5541
# Epoch: 86000, RMSE = 11.1461, 기울기 a = 1.4668, y 절편 b = 28.3396
# Epoch: 88000, RMSE = 10.4079, 기울기 a = 1.5021, y 절편 b = 27.1251
# Epoch: 90000, RMSE = 9.6698, 기울기 a = 1.5374, y 절편 b = 25.9106
# Epoch: 92000, RMSE = 8.9317, 기울기 a = 1.5727, y 절편 b = 24.6961
# Epoch: 94000, RMSE = 8.1936, 기울기 a = 1.6080, y 절편 b = 23.4816
# Epoch: 96000, RMSE = 7.4555, 기울기 a = 1.6433, y 절편 b = 22.2671
# Epoch: 98000, RMSE = 6.7173, 기울기 a = 1.6786, y 절편 b = 21.0526
# Epoch: 100000, RMSE = 5.9792, 기울기 a = 1.7140, y 절편 b = 19.8381
# Epoch: 102000, RMSE = 5.2411, 기울기 a = 1.7493, y 절편 b = 18.6236
# Epoch: 104000, RMSE = 4.5030, 기울기 a = 1.7846, y 절편 b = 17.4092
# Epoch: 106000, RMSE = 3.7649, 기울기 a = 1.8199, y 절편 b = 16.1947
# Epoch: 108000, RMSE = 3.0267, 기울기 a = 1.8552, y 절편 b = 14.9802
# Epoch: 110000, RMSE = 2.2886, 기울기 a = 1.8905, y 절편 b = 13.7657
# Epoch: 112000, RMSE = 1.5505, 기울기 a = 1.9258, y 절편 b = 12.5512
# Epoch: 114000, RMSE = 0.8124, 기울기 a = 1.9611, y 절편 b = 11.3367
# Epoch: 116000, RMSE = 0.3736, 기울기 a = 2.0044, y 절편 b = 10.2712
# v_rmse_min=%.4f v_a_min
# 학습률: 0.002
# Epoch: 0, RMSE = 224.6557, 기울기 a = 8.0154, y 절편 b = 80.6883
# Epoch: 2000, RMSE = 41.4087, 기울기 a = 0.0190, y 절편 b = 78.1334
# Epoch: 4000, RMSE = 39.9325, 기울기 a = 0.0896, y 절편 b = 75.7044
# Epoch: 6000, RMSE = 38.4562, 기울기 a = 0.1602, y 절편 b = 73.2754
# Epoch: 8000, RMSE = 36.9800, 기울기 a = 0.2309, y 절편 b = 70.8464
# Epoch: 10000, RMSE = 35.5038, 기울기 a = 0.3015, y 절편 b = 68.4174
# Epoch: 12000, RMSE = 34.0275, 기울기 a = 0.3721, y 절편 b = 65.9884
# Epoch: 14000, RMSE = 32.5513, 기울기 a = 0.4427, y 절편 b = 63.5594
# Epoch: 16000, RMSE = 31.0750, 기울기 a = 0.5134, y 절편 b = 61.1305
# Epoch: 18000, RMSE = 29.5988, 기울기 a = 0.5840, y 절편 b = 58.7015
# Epoch: 20000, RMSE = 28.1226, 기울기 a = 0.6546, y 절편 b = 56.2725
# Epoch: 22000, RMSE = 26.6463, 기울기 a = 0.7252, y 절편 b = 53.8435
# Epoch: 24000, RMSE = 25.1701, 기울기 a = 0.7958, y 절편 b = 51.4145
# Epoch: 26000, RMSE = 23.6938, 기울기 a = 0.8665, y 절편 b = 48.9855
# Epoch: 28000, RMSE = 22.2176, 기울기 a = 0.9371, y 절편 b = 46.5565
# Epoch: 30000, RMSE = 20.7414, 기울기 a = 1.0077, y 절편 b = 44.1275
# Epoch: 32000, RMSE = 19.2651, 기울기 a = 1.0783, y 절편 b = 41.6986
# Epoch: 34000, RMSE = 17.7889, 기울기 a = 1.1490, y 절편 b = 39.2696
# Epoch: 36000, RMSE = 16.3126, 기울기 a = 1.2196, y 절편 b = 36.8406
# Epoch: 38000, RMSE = 14.8364, 기울기 a = 1.2902, y 절편 b = 34.4116
# Epoch: 40000, RMSE = 13.3602, 기울기 a = 1.3608, y 절편 b = 31.9826
# Epoch: 42000, RMSE = 11.8839, 기울기 a = 1.4315, y 절편 b = 29.5536
# Epoch: 44000, RMSE = 10.4077, 기울기 a = 1.5021, y 절편 b = 27.1246
# Epoch: 46000, RMSE = 8.9314, 기울기 a = 1.5727, y 절편 b = 24.6957
# Epoch: 48000, RMSE = 7.4552, 기울기 a = 1.6433, y 절편 b = 22.2667
# Epoch: 50000, RMSE = 5.9790, 기울기 a = 1.7140, y 절편 b = 19.8377
# Epoch: 52000, RMSE = 4.5027, 기울기 a = 1.7846, y 절편 b = 17.4087
# Epoch: 54000, RMSE = 3.0265, 기울기 a = 1.8552, y 절편 b = 14.9797
# Epoch: 56000, RMSE = 1.5502, 기울기 a = 1.9258, y 절편 b = 12.5507
# Epoch: 58000, RMSE = 0.7473, 기울기 a = 2.0108, y 절편 b = 10.4910
# Epoch: 60000, RMSE = 0.7473, 기울기 a = 2.0253, y 절편 b = 10.0687
# Epoch: 62000, RMSE = 0.7473, 기울기 a = 2.0271, y 절편 b = 10.0102
# Epoch: 64000, RMSE = 0.7473, 기울기 a = 2.0273, y 절편 b = 10.0021
# Epoch: 66000, RMSE = 0.7473, 기울기 a = 2.0273, y 절편 b = 10.0010
# Epoch: 68000, RMSE = 0.7473, 기울기 a = 2.0273, y 절편 b = 10.0008
# Epoch: 70000, RMSE = 0.7473, 기울기 a = 2.0273, y 절편 b = 10.0008
# Epoch: 72000, RMSE = 0.7473, 기울기 a = 2.0273, y 절편 b = 10.0008
# Epoch: 74000, RMSE = 0.7473, 기울기 a = 2.0273, y 절편 b = 10.0008
# Epoch: 76000, RMSE = 0.7473, 기울기 a = 2.0273, y 절편 b = 10.0008
# Epoch: 78000, RMSE = 0.7473, 기울기 a = 2.0273, y 절편 b = 10.0008
# Epoch: 80000, RMSE = 0.7473, 기울기 a = 2.0273, y 절편 b = 10.0008
# Epoch: 82000, RMSE = 0.7473, 기울기 a = 2.0273, y 절편 b = 10.0008
# Epoch: 84000, RMSE = 0.7473, 기울기 a = 2.0273, y 절편 b = 10.0008
# Epoch: 86000, RMSE = 0.7473, 기울기 a = 2.0273, y 절편 b = 10.0008
# Epoch: 88000, RMSE = 0.7473, 기울기 a = 2.0273, y 절편 b = 10.0008
# Epoch: 90000, RMSE = 0.7473, 기울기 a = 2.0273, y 절편 b = 10.0008
# Epoch: 92000, RMSE = 0.7473, 기울기 a = 2.0273, y 절편 b = 10.0008
# Epoch: 94000, RMSE = 0.7473, 기울기 a = 2.0273, y 절편 b = 10.0008
# Epoch: 96000, RMSE = 0.7473, 기울기 a = 2.0273, y 절편 b = 10.0008
# Epoch: 98000, RMSE = 0.7473, 기울기 a = 2.0273, y 절편 b = 10.0008
# Epoch: 100000, RMSE = 0.7473, 기울기 a = 2.0273, y 절편 b = 10.0008
# Epoch: 102000, RMSE = 0.7473, 기울기 a = 2.0273, y 절편 b = 10.0008
# Epoch: 104000, RMSE = 0.7473, 기울기 a = 2.0273, y 절편 b = 10.0008
# Epoch: 106000, RMSE = 0.7473, 기울기 a = 2.0273, y 절편 b = 10.0008
# Epoch: 108000, RMSE = 0.7473, 기울기 a = 2.0273, y 절편 b = 10.0008
# Epoch: 110000, RMSE = 0.7473, 기울기 a = 2.0273, y 절편 b = 10.0008
# Epoch: 112000, RMSE = 0.7473, 기울기 a = 2.0273, y 절편 b = 10.0008
# Epoch: 114000, RMSE = 0.7473, 기울기 a = 2.0273, y 절편 b = 10.0008
# Epoch: 116000, RMSE = 0.7473, 기울기 a = 2.0273, y 절편 b = 10.0008
# v_rmse_min=%.4f v_a_min
# 학습률: 0.003
# Epoch: 0, RMSE = 223.9354, 기울기 a = 7.9885, y 절편 b = 80.6874
# Epoch: 2000, RMSE = 40.6703, 기울기 a = 0.0543, y 절편 b = 76.9184
# Epoch: 4000, RMSE = 38.4560, 기울기 a = 0.1602, y 절편 b = 73.2749
# Epoch: 6000, RMSE = 36.2416, 기울기 a = 0.2662, y 절편 b = 69.6315
# Epoch: 8000, RMSE = 34.0272, 기울기 a = 0.3721, y 절편 b = 65.9880
# Epoch: 10000, RMSE = 31.8129, 기울기 a = 0.4781, y 절편 b = 62.3445
# Epoch: 12000, RMSE = 29.5985, 기울기 a = 0.5840, y 절편 b = 58.7010
# Epoch: 14000, RMSE = 27.3842, 기울기 a = 0.6899, y 절편 b = 55.0575
# Epoch: 16000, RMSE = 25.1698, 기울기 a = 0.7959, y 절편 b = 51.4141
# Epoch: 18000, RMSE = 22.9554, 기울기 a = 0.9018, y 절편 b = 47.7706
# Epoch: 20000, RMSE = 20.7411, 기울기 a = 1.0077, y 절편 b = 44.1271
# Epoch: 22000, RMSE = 18.5267, 기울기 a = 1.1137, y 절편 b = 40.4836
# Epoch: 24000, RMSE = 16.3124, 기울기 a = 1.2196, y 절편 b = 36.8401
# Epoch: 26000, RMSE = 14.0980, 기울기 a = 1.3255, y 절편 b = 33.1967
# Epoch: 28000, RMSE = 11.8836, 기울기 a = 1.4315, y 절편 b = 29.5532
# Epoch: 30000, RMSE = 9.6693, 기울기 a = 1.5374, y 절편 b = 25.9097
# Epoch: 32000, RMSE = 7.4549, 기울기 a = 1.6434, y 절편 b = 22.2662
# Epoch: 34000, RMSE = 5.2406, 기울기 a = 1.7493, y 절편 b = 18.6227
# Epoch: 36000, RMSE = 3.0262, 기울기 a = 1.8552, y 절편 b = 14.9793
# Epoch: 38000, RMSE = 1.1203, 기울기 a = 1.9327, y 절편 b = 11.3742
# Epoch: 40000, RMSE = 1.1210, 기울기 a = 1.9537, y 절편 b = 10.1893
# Epoch: 42000, RMSE = 1.1210, 기울기 a = 1.9582, y 절편 b = 10.0252
# Epoch: 44000, RMSE = 1.1210, 기울기 a = 1.9589, y 절편 b = 10.0025
# Epoch: 46000, RMSE = 1.1210, 기울기 a = 1.9590, y 절편 b = 9.9993
# Epoch: 48000, RMSE = 1.1210, 기울기 a = 1.9590, y 절편 b = 9.9989
# Epoch: 50000, RMSE = 1.1210, 기울기 a = 1.9590, y 절편 b = 9.9988
# Epoch: 52000, RMSE = 1.1210, 기울기 a = 1.9590, y 절편 b = 9.9988
# Epoch: 54000, RMSE = 1.1210, 기울기 a = 1.9590, y 절편 b = 9.9988
# Epoch: 56000, RMSE = 1.1210, 기울기 a = 1.9590, y 절편 b = 9.9988
# Epoch: 58000, RMSE = 1.1210, 기울기 a = 1.9590, y 절편 b = 9.9988
# Epoch: 60000, RMSE = 1.1210, 기울기 a = 1.9590, y 절편 b = 9.9988
# Epoch: 62000, RMSE = 1.1210, 기울기 a = 1.9590, y 절편 b = 9.9988
# Epoch: 64000, RMSE = 1.1210, 기울기 a = 1.9590, y 절편 b = 9.9988
# Epoch: 66000, RMSE = 1.1210, 기울기 a = 1.9590, y 절편 b = 9.9988
# Epoch: 68000, RMSE = 1.1210, 기울기 a = 1.9590, y 절편 b = 9.9988
# Epoch: 70000, RMSE = 1.1210, 기울기 a = 1.9590, y 절편 b = 9.9988
# Epoch: 72000, RMSE = 1.1210, 기울기 a = 1.9590, y 절편 b = 9.9988
# Epoch: 74000, RMSE = 1.1210, 기울기 a = 1.9590, y 절편 b = 9.9988
# Epoch: 76000, RMSE = 1.1210, 기울기 a = 1.9590, y 절편 b = 9.9988
# Epoch: 78000, RMSE = 1.1210, 기울기 a = 1.9590, y 절편 b = 9.9988
# Epoch: 80000, RMSE = 1.1210, 기울기 a = 1.9590, y 절편 b = 9.9988
# Epoch: 82000, RMSE = 1.1210, 기울기 a = 1.9590, y 절편 b = 9.9988
# Epoch: 84000, RMSE = 1.1210, 기울기 a = 1.9590, y 절편 b = 9.9988
# Epoch: 86000, RMSE = 1.1210, 기울기 a = 1.9590, y 절편 b = 9.9988
# Epoch: 88000, RMSE = 1.1210, 기울기 a = 1.9590, y 절편 b = 9.9988
# Epoch: 90000, RMSE = 1.1210, 기울기 a = 1.9590, y 절편 b = 9.9988
# Epoch: 92000, RMSE = 1.1210, 기울기 a = 1.9590, y 절편 b = 9.9988
# Epoch: 94000, RMSE = 1.1210, 기울기 a = 1.9590, y 절편 b = 9.9988
# Epoch: 96000, RMSE = 1.1210, 기울기 a = 1.9590, y 절편 b = 9.9988
# Epoch: 98000, RMSE = 1.1210, 기울기 a = 1.9590, y 절편 b = 9.9988
# Epoch: 100000, RMSE = 1.1210, 기울기 a = 1.9590, y 절편 b = 9.9988
# Epoch: 102000, RMSE = 1.1210, 기울기 a = 1.9590, y 절편 b = 9.9988
# Epoch: 104000, RMSE = 1.1210, 기울기 a = 1.9590, y 절편 b = 9.9988
# Epoch: 106000, RMSE = 1.1210, 기울기 a = 1.9590, y 절편 b = 9.9988
# Epoch: 108000, RMSE = 1.1210, 기울기 a = 1.9590, y 절편 b = 9.9988
# Epoch: 110000, RMSE = 1.1210, 기울기 a = 1.9590, y 절편 b = 9.9988
# Epoch: 112000, RMSE = 1.1210, 기울기 a = 1.9590, y 절편 b = 9.9988
# Epoch: 114000, RMSE = 1.1210, 기울기 a = 1.9590, y 절편 b = 9.9988
# Epoch: 116000, RMSE = 1.1210, 기울기 a = 1.9590, y 절편 b = 9.9988
# v_rmse_min=%.4f v_a_min
# 학습률: 0.004
# Epoch: 0, RMSE = 223.2151, 기울기 a = 7.9617, y 절편 b = 80.6865
# Epoch: 2000, RMSE = 39.9319, 기울기 a = 0.0896, y 절편 b = 75.7035
# Epoch: 4000, RMSE = 36.9795, 기울기 a = 0.2309, y 절편 b = 70.8455
# Epoch: 6000, RMSE = 34.0270, 기울기 a = 0.3721, y 절편 b = 65.9875
# Epoch: 8000, RMSE = 31.0745, 기울기 a = 0.5134, y 절편 b = 61.1296
# Epoch: 10000, RMSE = 28.1220, 기울기 a = 0.6546, y 절편 b = 56.2716
# Epoch: 12000, RMSE = 25.1695, 기울기 a = 0.7959, y 절편 b = 51.4136
# Epoch: 14000, RMSE = 22.2170, 기울기 a = 0.9371, y 절편 b = 46.5556
# Epoch: 16000, RMSE = 19.2646, 기울기 a = 1.0784, y 절편 b = 41.6977
# Epoch: 18000, RMSE = 16.3121, 기울기 a = 1.2196, y 절편 b = 36.8397
# Epoch: 20000, RMSE = 13.3596, 기울기 a = 1.3609, y 절편 b = 31.9817
# Epoch: 22000, RMSE = 10.4071, 기울기 a = 1.5021, y 절편 b = 27.1237
# Epoch: 24000, RMSE = 7.4546, 기울기 a = 1.6434, y 절편 b = 22.2658
# Epoch: 26000, RMSE = 4.5022, 기울기 a = 1.7846, y 절편 b = 17.4078
# Epoch: 28000, RMSE = 1.5497, 기울기 a = 1.9259, y 절편 b = 12.5498
# Epoch: 30000, RMSE = 1.4946, 기울기 a = 2.0440, y 절편 b = 10.3491
# Epoch: 32000, RMSE = 1.4947, 기울기 a = 2.0532, y 절편 b = 10.0498
# Epoch: 34000, RMSE = 1.4947, 기울기 a = 2.0545, y 절편 b = 10.0083
# Epoch: 36000, RMSE = 1.4947, 기울기 a = 2.0546, y 절편 b = 10.0025
# Epoch: 38000, RMSE = 1.4947, 기울기 a = 2.0546, y 절편 b = 10.0017
# Epoch: 40000, RMSE = 1.4947, 기울기 a = 2.0547, y 절편 b = 10.0016
# Epoch: 42000, RMSE = 1.4947, 기울기 a = 2.0547, y 절편 b = 10.0016
# Epoch: 44000, RMSE = 1.4947, 기울기 a = 2.0547, y 절편 b = 10.0016
# Epoch: 46000, RMSE = 1.4947, 기울기 a = 2.0547, y 절편 b = 10.0016
# Epoch: 48000, RMSE = 1.4947, 기울기 a = 2.0547, y 절편 b = 10.0016
# Epoch: 50000, RMSE = 1.4947, 기울기 a = 2.0547, y 절편 b = 10.0016
# Epoch: 52000, RMSE = 1.4947, 기울기 a = 2.0547, y 절편 b = 10.0016
# Epoch: 54000, RMSE = 1.4947, 기울기 a = 2.0547, y 절편 b = 10.0016
# Epoch: 56000, RMSE = 1.4947, 기울기 a = 2.0547, y 절편 b = 10.0016
# Epoch: 58000, RMSE = 1.4947, 기울기 a = 2.0547, y 절편 b = 10.0016
# Epoch: 60000, RMSE = 1.4947, 기울기 a = 2.0547, y 절편 b = 10.0016
# Epoch: 62000, RMSE = 1.4947, 기울기 a = 2.0547, y 절편 b = 10.0016
# Epoch: 64000, RMSE = 1.4947, 기울기 a = 2.0547, y 절편 b = 10.0016
# Epoch: 66000, RMSE = 1.4947, 기울기 a = 2.0547, y 절편 b = 10.0016
# Epoch: 68000, RMSE = 1.4947, 기울기 a = 2.0547, y 절편 b = 10.0016
# Epoch: 70000, RMSE = 1.4947, 기울기 a = 2.0547, y 절편 b = 10.0016
# Epoch: 72000, RMSE = 1.4947, 기울기 a = 2.0547, y 절편 b = 10.0016
# Epoch: 74000, RMSE = 1.4947, 기울기 a = 2.0547, y 절편 b = 10.0016
# Epoch: 76000, RMSE = 1.4947, 기울기 a = 2.0547, y 절편 b = 10.0016
# Epoch: 78000, RMSE = 1.4947, 기울기 a = 2.0547, y 절편 b = 10.0016
# Epoch: 80000, RMSE = 1.4947, 기울기 a = 2.0547, y 절편 b = 10.0016
# Epoch: 82000, RMSE = 1.4947, 기울기 a = 2.0547, y 절편 b = 10.0016
# Epoch: 84000, RMSE = 1.4947, 기울기 a = 2.0547, y 절편 b = 10.0016
# Epoch: 86000, RMSE = 1.4947, 기울기 a = 2.0547, y 절편 b = 10.0016
# Epoch: 88000, RMSE = 1.4947, 기울기 a = 2.0547, y 절편 b = 10.0016
# Epoch: 90000, RMSE = 1.4947, 기울기 a = 2.0547, y 절편 b = 10.0016
# Epoch: 92000, RMSE = 1.4947, 기울기 a = 2.0547, y 절편 b = 10.0016
# Epoch: 94000, RMSE = 1.4947, 기울기 a = 2.0547, y 절편 b = 10.0016
# Epoch: 96000, RMSE = 1.4947, 기울기 a = 2.0547, y 절편 b = 10.0016
# Epoch: 98000, RMSE = 1.4947, 기울기 a = 2.0547, y 절편 b = 10.0016
# Epoch: 100000, RMSE = 1.4947, 기울기 a = 2.0547, y 절편 b = 10.0016
# Epoch: 102000, RMSE = 1.4947, 기울기 a = 2.0547, y 절편 b = 10.0016
# Epoch: 104000, RMSE = 1.4947, 기울기 a = 2.0547, y 절편 b = 10.0016
# Epoch: 106000, RMSE = 1.4947, 기울기 a = 2.0547, y 절편 b = 10.0016
# Epoch: 108000, RMSE = 1.4947, 기울기 a = 2.0547, y 절편 b = 10.0016
# Epoch: 110000, RMSE = 1.4947, 기울기 a = 2.0547, y 절편 b = 10.0016
# Epoch: 112000, RMSE = 1.4947, 기울기 a = 2.0547, y 절편 b = 10.0016
# Epoch: 114000, RMSE = 1.4947, 기울기 a = 2.0547, y 절편 b = 10.0016
# Epoch: 116000, RMSE = 1.4947, 기울기 a = 2.0547, y 절편 b = 10.0016
# v_rmse_min=%.4f v_a_min
# 최소의 평균 제곱근 오차: 0.37362096589496097
# 학습된 선형회귀 공식: f(x) = 2.0044x + 10.2712

# %%
# 테스트, 검증
# 최소의 평균 제곱근 오차: 0.373620965895
# 학습된 선형회귀 공식: f(x) = 2.0044x + 10.2712
    
test_x=[37, 43, 50]
test_y=[84, 96, 110]
for i in range(len(test_x)):
    predict = v_a_min * test_x[i] + v_b_min  # y = ax + b, y = 2.3x + 79 가정
    print('데이터: %d 실제: %d 예측 %d' % (test_x[i], test_y[i], predict))
# Out:
# 데이터: 37 실제: 84 예측 84
# 데이터: 43 실제: 96 예측 96
# 데이터: 50 실제: 110 예측 110
